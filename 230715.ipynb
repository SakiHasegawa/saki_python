# %%
import random
students = []
for _ in range (50):
    stu = list()
    for _ in range(5):
        stu.append(random.randint(50,100))
    students.append(stu)
students
# Out:
# [[91, 62, 78, 54, 100],
#  [70, 66, 98, 78, 71],
#  [73, 63, 53, 100, 88],
#  [79, 80, 63, 67, 89],
#  [93, 86, 69, 59, 67],
#  [89, 95, 63, 68, 61],
#  [58, 67, 100, 59, 97],
#  [89, 86, 72, 70, 86],
#  [87, 70, 75, 68, 95],
#  [77, 95, 97, 62, 86],
#  [78, 100, 55, 84, 67],
#  [87, 50, 98, 73, 82],
#  [58, 88, 95, 50, 98],
#  [61, 74, 70, 61, 70],
#  [60, 54, 75, 58, 94],
#  [64, 87, 91, 60, 92],
#  [99, 61, 77, 97, 81],
#  [52, 53, 67, 82, 92],
#  [96, 63, 71, 79, 56],
#  [50, 57, 77, 92, 50],
#  [97, 62, 63, 90, 58],
#  [84, 77, 57, 54, 91],
#  [63, 71, 90, 89, 75],
#  [73, 65, 93, 92, 69],
#  [98, 51, 69, 93, 58],
#  [60, 73, 60, 57, 92],
#  [59, 71, 84, 96, 88],
#  [74, 67, 55, 81, 54],
#  [91, 95, 95, 94, 82],
#  [52, 73, 72, 52, 92],
#  [75, 76, 65, 90, 95],
#  [68, 67, 90, 87, 92],
#  [87, 53, 90, 51, 90],
#  [97, 90, 79, 81, 57],
#  [75, 59, 61, 79, 62],
#  [99, 51, 98, 50, 81],
#  [52, 63, 91, 53, 62],
#  [66, 66, 52, 68, 64],
#  [93, 73, 64, 89, 56],
# ...
