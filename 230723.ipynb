# %%
import csv
filename = 'aqx_p_432.csv'
with open(filename,encoding='utf-8',newline='') as file:
    data = csv.DictReader(file)
    data_list = list(data)

data_list
# Out:
# [{'sitename': '基隆',
#   'county': '基隆市',
#   'aqi': '19',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.8',
#   'co': '0.26',
#   'o3': '19.2',
#   'o3_8hr': '21.8',
#   'pm10': '',
#   'pm2.5': '7',
#   'no2': '10.1',
#   'nox': '11.4',
#   'no': '1.3',
#   'wind_speed': '0.2',
#   'wind_direc': '185',
#   'publishtime': '2023/07/23 20:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '6',
#   'pm10_avg': '',
#   'so2_avg': '1',
#   'longitude': '121.760056',
#   'latitude': '25.129167',
#   'siteid': '1'},
#  {'sitename': '汐止',
#   'county': '新北市',
#   'aqi': '26',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.4',
#   'co': '0.33',
#   'o3': '13.4',
#   'o3_8hr': '28.5',
#   'pm10': '12',
#   'pm2.5': '9',
#   'no2': '15.5',
#   'nox': '18',
#   'no': '2.5',
#   'wind_speed': '0.8',
#   'wind_direc': '212',
#   'publishtime': '2023/07/23 20:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '6.1',
#   'pm10_avg': '12',
#   'so2_avg': '0',
#   'longitude': '121.64081',
# ...
