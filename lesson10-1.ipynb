# %%
import json
with open('F-C0032-001.json',encoding = 'utf-8') as file:
    json_str = file.read()
    weather = json.loads(json_str)
print(weather)
# Out:
# {'cwbopendata': {'@xmlns': 'urn:cwb:gov:tw:cwbcommon:0.1', 'identifier': 'e0c3f208-f68c-2207-9fbf-a44a48845ee9', 'sender': 'weather@cwb.gov.tw', 'sent': '2023-07-24T03:57:01+08:00', 'status': 'Actual', 'msgType': 'Issue', 'source': 'MFC', 'dataid': 'C0032-001', 'scope': 'Public', 'dataset': {'datasetInfo': {'datasetDescription': '三十六小時天氣預報', 'issueTime': '2023-07-24T05:00:00+08:00', 'update': '2023-07-24T03:57:01+08:00'}, 'location': [{'locationName': '臺北市', 'weatherElement': [{'elementName': 'Wx', 'time': [{'startTime': '2023-07-24T06:00:00+08:00', 'endTime': '2023-07-24T18:00:00+08:00', 'parameter': {'parameterName': '多雲時晴', 'parameterValue': '3'}}, {'startTime': '2023-07-24T18:00:00+08:00', 'endTime': '2023-07-25T06:00:00+08:00', 'parameter': {'parameterName': '多雲', 'parameterValue': '4'}}, {'startTime': '2023-07-25T06:00:00+08:00', 'endTime': '2023-07-25T18:00:00+08:00', 'parameter': {'parameterName': '多雲時陰', 'parameterValue': '5'}}]}, {'elementName': 'MaxT', 'time': [{'startTime': '2023-07-24T06:00:00+08:00', 'endTime': '2023-07-24T18:00:00+08:00', 'parameter': {'parameterName': '35', 'parameterUnit': 'C'}}, {'startTime': '2023-07-24T18:00:00+08:00', 'endTime': '2023-07-25T06:00:00+08:00', 'parameter': {'parameterName': '32', 'parameterUnit': 'C'}}, {'startTime': '2023-07-25T06:00:00+08:00', 'endTime': '2023-07-25T18:00:00+08:00', 'parameter': {'parameterName': '34', 'parameterUnit': 'C'}}]}, {'elementName': 'MinT', 'time': [{'startTime': '2023-07-24T06:00:00+08:00', 'endTime': '2023-07-24T18:00:00+08:00', 'parameter': {'parameterName': '27', 'parameterUnit': 'C'}}, {'startTime': '2023-07-24T18:00:00+08:00', 'endTime': '2023-07-25T06:00:00+08:00', 'parameter': {'parameterName': '27', 'parameterUnit': 'C'}}, {'startTime': '2023-07-25T06:00:00+08:00', 'endTime': '2023-07-25T18:00:00+08:00', 'parameter': {'parameterName': '27', 'parameterUnit': 'C'}}]}, {'elementName': 'CI', 'time': [{'startTime': '2023-07-24T06:00:00+08:00', 'endTime': '2023-07-24T18:00:00+08:00', 'parameter': {'parameterName': '舒適至悶熱'}}, {'startTime': '2023-07-24T18:00:00+08:00', 'endTime': '2023-07-25T06:00:00+08:00', 'parameter': {'parameterName': '舒適至悶熱'}}, {'startTime': '2023-07-25T06:00:00+08:00', 'endTime': '2023-07-25T18:00:00+08:00', 'parameter': {'parameterName': '舒適至悶熱'}}]}, {'elementName': 'PoP', 'time': [{'startTime': '2023-07-24T06:00:00+08:00', 'endTime': '2023-07-24T18:00:00+08:00', 'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}}, {'startTime': '2023-07-24T18:00:00+08:00', 'endTime': '2023-07-25T06:00:00+08:00', 'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}}, {'startTime': '2023-07-25T06:00:00+08:00', 'endTime': '2023-07-25T18:00:00+08:00', 'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}}]}]}, {'locationName': '新北市', 'weatherElement': [{'elementName': 'Wx', 'time': [{'startTime': '2023-07-24T06:00:00+08:00', 'endTime': '2023-07-24T18:00:00+08:00', 'parameter': {'parameterName': '多雲時晴', 'parameterValue': '3'}}, {'startTime': '2023-07-24T18:00:00+08:00', 'endTime': '2023-07-25T06:00:00+08:00', 'parameter': {'parameterName': '多雲', 'parameterValue': '4'}}, {'startTime': '2023-07-25T06:00:00+08:00', 'endTime': '2023-07-25T18:00:00+08:00', 'parameter': {'parameterName': '多雲', 'parameterValue': '4'}}]}, {'elementName': 'MaxT', 'time': [{'startTime': '2023-07-24T06:00:00+08:00', 'endTime': '2023-07-24T18:00:00+08:00', 'parameter': {'parameterName': '34', 'parameterUnit': 'C'}}, {'startTime': '2023-07-24T18:00:00+08:00', 'endTime': '2023-07-25T06:00:00+08:00', 'parameter': {'parameterName': '31', 'parameterUnit': 'C'}}, {'startTime': '2023-07-25T06:00:00+08:00', 'endTime': '2023-07-25T18:00:00+08:00', 'parameter': {'parameterName': '34', 'parameterUnit': 'C'}}]}, {'elementName': 'MinT', 'time': [{'startTime': '2023-07-24T06:00:00+08:00', 'endTime': '2023-07-24T18:00:00+08:00', 'parameter': {'parameterName': '27', 'parameterUnit': 'C'}}, {'startTime': '2023-07-24T18:00:00+08:00', 'endTime': '2023-07-25T06:00:00 ...

# %%
location = weather['cwbopendata']['dataset']['location']
weather_list = []
for item in location:
    city_item = {}
    city_item['城市'] = item['locationName']
    city_item['啟始時間'] = item['weatherElement'][1]['time'][0]['startTime']
    city_item['結束時間'] = item['weatherElement'][1]['time'][0]['endTime']
    city_item['最高溫度'] = float(item['weatherElement'][1]['time'][0]['parameter']['parameterName'])
    city_item['最低溫度'] = float(item['weatherElement'][2]['time'][0]['parameter']['parameterName'])
    city_item['感覺'] = item['weatherElement'][3]['time'][0]['parameter']['parameterName']
    weather_list.append(city_item)
weather_list
# Out:
# [{'城市': '臺北市',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 35.0,
#   '最低溫度': 27.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '新北市',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 27.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '桃園市',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 35.0,
#   '最低溫度': 27.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '臺中市',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 35.0,
#   '最低溫度': 27.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '臺南市',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 33.0,
#   '最低溫度': 28.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '高雄市',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 28.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '基隆市',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 33.0,
#   '最低溫度': 28.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '新竹縣',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 27.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '新竹市',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 33.0,
#   '最低溫度': 27.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '苗栗縣',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '彰化縣',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 27.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '南投縣',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 35.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '雲林縣',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '嘉義縣',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 35.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '嘉義市',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 35.0,
#   '最低溫度': 25.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '屏東縣',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 35.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '宜蘭縣',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 33.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '花蓮縣',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 32.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '臺東縣',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 32.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '澎湖縣',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 33.0,
#   '最低溫度': 28.0,
#   '感覺': '悶熱'},
#  {'城市': '金門縣',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 33.0,
#   '最低溫度': 27.0,
#   '感覺': '悶熱'},
#  {'城市': '連江縣',
#   '啟始時間': '2023-07-24T06:00:00+08:00',
#   '結束時間': '2023-07-24T18:00:00+08:00',
#   '最高溫度': 32.0,
#   '最低溫度': 27.0,
#   '感覺': '悶熱'}]

# %%
import csv
with open('目前天氣.csv',mode='w',encoding='utf-8',newline='') as file:
    fieldnames = ['城市', '啟始時間','結束時間','最高溫度','最低溫度','感覺']
    writer = csv.DictWriter(file,fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(weather_list)
