# %%
#pip install --upgrade pandas
import numpy as np
n1 = np.random.randint(50,100,size=(10,))
n1
# Out:
# array([69, 61, 94, 60, 65, 72, 52, 74, 50, 54])

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html
#
# https://pandas.pydata.org/docs/reference/api/pandas.Series.html
#
# https://numpy.org/doc/stable/reference/
#
# https://matplotlib.org/stable/api/index.html

# %%
import numpy as np
import pandas as pd

n1 = np.random.randint(200,300,size=(10,))
s1 = pd.Series(data=n1,index=[f"學生{i+1}" for i in range(10)])
display(s1+100)
display(s1.values)
display(s1.index)
# Out:
# 學生1     308
# 學生2     323
# 學生3     316
# 學生4     347
# 學生5     305
# 學生6     371
# 學生7     350
# 學生8     327
# 學生9     344
# 學生10    362
# dtype: int64
# array([208, 223, 216, 247, 205, 271, 250, 227, 244, 262])
# Index(['學生1', '學生2', '學生3', '學生4', '學生5', '學生6', '學生7', '學生8', '學生9', '學生10'], dtype='object')

# %%
import requests
import pandas as pd

# 設定time為獲取中文姓名100筆的倍數。time=3，就是300筆的意思。
times = 1
cnames = []
for x in range(times):
    url = 'http://www.richyli.com/name/index.asp'
    r = requests.get(url)
    r.encoding = 'big5'
    
    # 將網頁中的資料以分行的方式存成文字檔
    result = r.text.splitlines()
    
    # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
    char_index = result[114].rfind("、")
    temp = result[114][:char_index]
    
    # 將temp的100筆姓名新增到cnames中
    cnames.append(temp)

# 將每100筆姓名的list加一個「、」，再組合成字串存到my_names中
my_names = "、".join(str(x) for x in cnames)
print(my_names)
# Out:
# 溫雅雯、游筱雯、倪彥廷、張靜雯、陳宜真、林正裕、陳昕聖、陳金禾、吳嘉東、謝旺華、童家瑋、楊雅玲、周永清、吳慧人、許松雨、溥美玲、劉耀雨、李明昇、陳百夫、韓佳芳、陳偉能、李易坤、楊志城、林子士、鄧祐玲、盧雅文、張明佳、陳玟秀、索健銘、廖玉婷、高雅馨、趙孟穎、林興淑、鄭雅貴、王筱芸、黃淑芳、林淑喬、羅韻嘉、李軍城、陳俊霖、林婉婷、王耀文、郭松啟、詹淑君、宋婉玲、梁有睿、吳湖靖、何倍俐、陳若筠、溫雅萍、黃建育、邱淑茜、林佩新、黃惠恭、林又清、高彥廷、黃玉婷、洪則�琚B馬政霖、林俊成、馮佳霖、林雯蕙、陸志竹、牛庭平、林苑婷、林瑋雲、張孟珮、楊書州、林展劭、賴明倫、李佳菁、許明儒、吳雅芬、林美慧、高韻斌、陳貞儀、盧正樂、崔素和、吳文凱、高美珠、劉貞軍、陳家華、柳胤堯、王明文、陳振念、翁敬漢、吳英俊、陳雅玲、溫紀吉、傅欣瑜、黃展冰、黃瓊青、陳宗茹、夏惠如、陳家瑋、涂可欣、馮瑩芸、賴宇翔、吳得禎、汪舜易

# %%
import requests
def getNames(num):
    times = 1
    cnames = []
    for x in range(times):
        url = 'http://www.richyli.com/name/index.asp'
        r = requests.get(url)
        r.encoding = 'big5'
        
        # 將網頁中的資料以分行的方式存成文字檔
        result = r.text.splitlines()
        
        # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
        char_index = result[114].rfind("、")
        temp = result[114][:char_index]
        
        # 將temp的100筆姓名新增到cnames中
        cnames.append(temp)
    print(type(cnames[0]))
    names = cnames[0].split('、')
    return names[:num]


names = getNames(50)
# Out:
# <class 'str'>

# %%
import numpy as np
import pandas as pd

n2 = np.random.randint(50,100,size=(50,5))
dataFrame = pd.DataFrame(data=n2,
             index=names[:50],
             columns=["國文","英文","數學","地理","歷史"]
             )
dataFrame
# Out:
#      國文  英文  數學  地理  歷史
# 曾冠中  60  62  51  87  84
# 黃宛蓉  72  52  54  86  80
# 林怡菁  51  97  54  75  78
# 曾淑安  80  92  56  70  66
# 楊怡靜  55  86  55  95  58
# 陳惠珠  80  97  60  90  75
# 鄧淑惠  61  71  74  85  72
# 吳琬婷  56  79  90  77  53
# 黃倍容  84  71  67  75  94
# 林惠珠  52  95  75  58  86
# 陳佳紋  53  84  93  73  65
# 曹守聿  75  98  69  59  50
# 盧智典  91  86  81  96  69
# 楊茹寧  79  87  98  69  55
# 林育誠  92  96  77  63  73
# 李雅琬  87  62  82  65  92
# 祖淑惠  86  77  71  79  93
# 陳虹利  72  92  95  85  97
# 李俊駿  96  94  88  60  82
# 李宜瑄  70  97  90  91  66
# 黃家斌  72  75  76  63  94
# 林惠婷  68  70  63  99  94
# 陳怡州  91  51  74  94  63
# 蘇侑陽  87  79  83  95  70
# 黃筱凡  81  73  97  90  78
# 丁金鳳  74  61  59  64  98
# 張世傑  77  96  64  99  53
# 張雅伯  59  98  96  68  66
# 陳怡婷  82  52  96  58  52
# 游淑華  98  72  76  59  69
# 孫怡廷  50  54  78  75  98
# 黃佩君  56  60  69  65  82
# 蔡馨儀  64  74  60  97  74
# 李鈺汝  85  98  77  89  88
# 黃琬婷  51  57  74  74  75
# 黃千慧  88  87  74  56  81
# 汪忠舜  93  50  74  70  66
# 羅雅婷  91  92  95  78  95
# 林哲雄  91  99  89  65  89
# 駱承恩  90  54  82  54  56
# 鞠慧君  76  76  87  55  77
# 劉怡君  57  98  64  98  61
# 林書海  84  98  50  61  97
# 黃麗妃  80  94  80  90  67
# 周信宏  99  67  94  84  72
# 林姿穎  79  85  80  72  94
# 李易郁  75  50  70  72  51
# 沈哲銘  88  61  92  90  62
# 駱安慈  64  65  74  97  57
# 曾憶政  76  93  99  99  91

# %%
dataFrame["國文"]
dataFrame[["國文","英文"]]
total = dataFrame["國文"] + dataFrame["英文"] + dataFrame["數學"] + dataFrame["地理"] + dataFrame["歷史"]
dataFrame["總分"] = total 
dataFrame
# Out:
#      國文  英文  數學  地理  歷史   總分
# 曾冠中  60  62  51  87  84  344
# 黃宛蓉  72  52  54  86  80  344
# 林怡菁  51  97  54  75  78  355
# 曾淑安  80  92  56  70  66  364
# 楊怡靜  55  86  55  95  58  349
# 陳惠珠  80  97  60  90  75  402
# 鄧淑惠  61  71  74  85  72  363
# 吳琬婷  56  79  90  77  53  355
# 黃倍容  84  71  67  75  94  391
# 林惠珠  52  95  75  58  86  366
# 陳佳紋  53  84  93  73  65  368
# 曹守聿  75  98  69  59  50  351
# 盧智典  91  86  81  96  69  423
# 楊茹寧  79  87  98  69  55  388
# 林育誠  92  96  77  63  73  401
# 李雅琬  87  62  82  65  92  388
# 祖淑惠  86  77  71  79  93  406
# 陳虹利  72  92  95  85  97  441
# 李俊駿  96  94  88  60  82  420
# 李宜瑄  70  97  90  91  66  414
# 黃家斌  72  75  76  63  94  380
# 林惠婷  68  70  63  99  94  394
# 陳怡州  91  51  74  94  63  373
# 蘇侑陽  87  79  83  95  70  414
# 黃筱凡  81  73  97  90  78  419
